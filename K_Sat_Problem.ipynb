# %% [markdown]
# <a href="https://colab.research.google.com/github/tushant-akar/CS367-Artifical-Intelligence-Lab/blob/main/K_Sat_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time
from typing import List, Tuple, Callable

# %%
def generate_ksat_problem(k, m, n):
    formula = []

    for _ in range(m):
        # Generate a new clause
        clause = []
        available_vars = list(range(1, n + 1))

        for _ in range(k):
            if not available_vars:
                break

            # Choose a random variable from the available ones
            var = random.choice(available_vars)
            available_vars.remove(var)

            # Randomly negate the variable or not
            if random.random() < 0.5:
                var = -var

            clause.append(var)

        formula.append(clause)

    return formula

# %%
def print_formula(formula):
    print("Formula:")
    for i, clause in enumerate(formula, 1):
        clause_str = " ∨ ".join(map(str, clause))
        print(f"  ({clause_str})")
    print()

# %%
def heuristic1(assignment: List[bool], formula: List[List[int]]) -> int:
    return sum(any(literal > 0 and assignment[abs(literal) - 1] or
                   literal < 0 and not assignment[abs(literal) - 1]
                   for literal in clause)
               for clause in formula)

def heuristic2(assignment: List[bool], formula: List[List[int]]) -> int:
    return sum(2 ** sum(literal > 0 and assignment[abs(literal) - 1] or
                        literal < 0 and not assignment[abs(literal) - 1]
                        for literal in clause)
               for clause in formula)

# %%
def hill_climbing(formula: List[List[int]], n: int, heuristic: Callable, max_iterations: int = 1000) -> Tuple[List[bool], int]:
    assignment = [random.choice([True, False]) for _ in range(n)]
    best_score = heuristic(assignment, formula)

    for _ in range(max_iterations):
        improved = False
        for i in range(n):
            new_assignment = assignment.copy()
            new_assignment[i] = not new_assignment[i]
            new_score = heuristic(new_assignment, formula)
            if new_score > best_score:
                assignment = new_assignment
                best_score = new_score
                improved = True
                break
        if not improved:
            break

    return assignment, best_score

# %%
def beam_search(formula: List[List[int]], n: int, heuristic: Callable, beam_width: int, max_iterations: int = 1000) -> Tuple[List[bool], int]:
    beam = [[random.choice([True, False]) for _ in range(n)] for _ in range(beam_width)]
    best_assignment = None
    best_score = -1

    for _ in range(max_iterations):
        candidates = []
        for assignment in beam:
            for i in range(n):
                new_assignment = assignment.copy()
                new_assignment[i] = not new_assignment[i]
                score = heuristic(new_assignment, formula)
                candidates.append((new_assignment, score))

        candidates.sort(key=lambda x: x[1], reverse=True)
        beam = [candidate[0] for candidate in candidates[:beam_width]]

        if candidates[0][1] > best_score:
            best_assignment, best_score = candidates[0]

    return best_assignment, best_score

# %%
def vnd(formula: List[List[int]], n: int, heuristic: Callable, neighborhood_functions: List[Callable], max_iterations: int = 1000) -> Tuple[List[bool], int]:
    assignment = [random.choice([True, False]) for _ in range(n)]
    best_score = heuristic(assignment, formula)

    for _ in range(max_iterations):
        improved = False
        for nf in neighborhood_functions:
            new_assignment = nf(assignment)
            new_score = heuristic(new_assignment, formula)
            if new_score > best_score:
                assignment = new_assignment
                best_score = new_score
                improved = True
                break
        if not improved:
            break

    return assignment, best_score

# Neighborhood functions for VND
def flip_one(assignment: List[bool]) -> List[bool]:
    new_assignment = assignment.copy()
    i = random.randint(0, len(assignment) - 1)
    new_assignment[i] = not new_assignment[i]
    return new_assignment

def flip_two(assignment: List[bool]) -> List[bool]:
    new_assignment = assignment.copy()
    i, j = random.sample(range(len(assignment)), 2)
    new_assignment[i] = not new_assignment[i]
    new_assignment[j] = not new_assignment[j]
    return new_assignment

def swap_two(assignment: List[bool]) -> List[bool]:
    new_assignment = assignment.copy()
    i, j = random.sample(range(len(assignment)), 2)
    new_assignment[i], new_assignment[j] = new_assignment[j], new_assignment[i]
    return new_assignment

# %%
def calculate_penetrance(scores: List[int], max_score: int) -> float:
    return sum(score == max_score for score in scores) / len(scores)

# %%
def compare_algorithms(m: int, n: int, num_problems: int = 10, max_iterations: int = 500):
    algorithms = [
        ("Hill Climbing", lambda f, n, h: hill_climbing(f, n, h, max_iterations)),
        ("Beam Search (w=3)", lambda f, n, h: beam_search(f, n, h, 3, max_iterations)),
        ("Beam Search (w=4)", lambda f, n, h: beam_search(f, n, h, 4, max_iterations)),
        ("VND", lambda f, n, h: vnd(f, n, h, [flip_one, flip_two, swap_two], max_iterations))
    ]

    heuristics = [
        ("Heuristic 1", heuristic1),
        ("Heuristic 2", heuristic2)
    ]

    results = {(alg_name, heur_name): [] for alg_name, _ in algorithms for heur_name, _ in heuristics}

    for _ in range(num_problems):
        formula = generate_ksat_problem(3, m, n)
        max_score = m  # Maximum possible score is the number of clauses

        for (alg_name, algorithm), (heur_name, heuristic) in [(a, h) for a in algorithms for h in heuristics]:
            start_time = time.time()
            _, score = algorithm(formula, n, heuristic)
            elapsed_time = time.time() - start_time
            results[(alg_name, heur_name)].append((score, elapsed_time))

    print(f"Results for m={m}, n={n}:")
    for (alg_name, heur_name), scores_times in results.items():
        scores, times = zip(*scores_times)
        avg_score = sum(scores) / len(scores)
        avg_time = sum(times) / len(times)
        penetrance = calculate_penetrance(scores, max_score)
        print(f"  {alg_name} with {heur_name}:")
        print(f"    Average Score: {avg_score:.2f}")
        print(f"    Average Time: {avg_time:.4f} seconds")
        print(f"    Penetrance: {penetrance:.2%}")
        print()

# %%
if __name__ == "__main__":
    m_values = [25, 75, 150]
    n_values = [10, 43, 78]

    for m in m_values:
        for n in n_values:
            compare_algorithms(m, n)
            print("=" * 50)
# Out:
# Results for m=25, n=10:
#   Hill Climbing with Heuristic 1:
#     Average Score: 24.80
#     Average Time: 0.0004 seconds
#     Penetrance: 80.00%
#
#   Hill Climbing with Heuristic 2:
#     Average Score: 112.60
#     Average Time: 0.0012 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=3) with Heuristic 1:
#     Average Score: 24.90
#     Average Time: 0.3137 seconds
#     Penetrance: 90.00%
#
#   Beam Search (w=3) with Heuristic 2:
#     Average Score: 113.20
#     Average Time: 0.4612 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=4) with Heuristic 1:
#     Average Score: 25.00
#     Average Time: 0.4236 seconds
#     Penetrance: 100.00%
#
#   Beam Search (w=4) with Heuristic 2:
#     Average Score: 113.20
#     Average Time: 0.6042 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 1:
#     Average Score: 23.60
#     Average Time: 0.0002 seconds
#     Penetrance: 10.00%
#
#   VND with Heuristic 2:
#     Average Score: 95.90
#     Average Time: 0.0002 seconds
#     Penetrance: 0.00%
#
# ==================================================
# Results for m=25, n=43:
#   Hill Climbing with Heuristic 1:
#     Average Score: 25.00
#     Average Time: 0.0019 seconds
#     Penetrance: 100.00%
#
#   Hill Climbing with Heuristic 2:
#     Average Score: 143.40
#     Average Time: 0.0145 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=3) with Heuristic 1:
#     Average Score: 25.00
#     Average Time: 1.3398 seconds
#     Penetrance: 100.00%
#
#   Beam Search (w=3) with Heuristic 2:
#     Average Score: 143.40
#     Average Time: 2.1242 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=4) with Heuristic 1:
#     Average Score: 25.00
#     Average Time: 1.7895 seconds
#     Penetrance: 100.00%
#
#   Beam Search (w=4) with Heuristic 2:
#     Average Score: 143.70
#     Average Time: 2.7810 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 1:
#     Average Score: 22.50
#     Average Time: 0.0002 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 2:
#     Average Score: 93.30
#     Average Time: 0.0003 seconds
#     Penetrance: 0.00%
#
# ==================================================
# Results for m=25, n=78:
#   Hill Climbing with Heuristic 1:
#     Average Score: 25.00
#     Average Time: 0.0029 seconds
#     Penetrance: 100.00%
#
#   Hill Climbing with Heuristic 2:
#     Average Score: 160.20
#     Average Time: 0.0331 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=3) with Heuristic 1:
#     Average Score: 25.00
#     Average Time: 2.3960 seconds
#     Penetrance: 100.00%
#
#   Beam Search (w=3) with Heuristic 2:
#     Average Score: 161.10
#     Average Time: 3.6173 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=4) with Heuristic 1:
#     Average Score: 25.00
#     Average Time: 3.3668 seconds
#     Penetrance: 100.00%
#
#   Beam Search (w=4) with Heuristic 2:
#     Average Score: 159.70
#     Average Time: 5.2151 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 1:
#     Average Score: 23.00
#     Average Time: 0.0002 seconds
#     Penetrance: 20.00%
#
#   VND with Heuristic 2:
#     Average Score: 88.30
#     Average Time: 0.0002 seconds
#     Penetrance: 0.00%
#
# ==================================================
# Results for m=75, n=10:
#   Hill Climbing with Heuristic 1:
#     Average Score: 71.60
#     Average Time: 0.0016 seconds
#     Penetrance: 0.00%
#
#   Hill Climbing with Heuristic 2:
#     Average Score: 304.00
#     Average Time: 0.0044 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=3) with Heuristic 1:
#     Average Score: 72.90
#     Average Time: 0.9852 seconds
#     Penetrance: 10.00%
#
#   Beam Search (w=3) with Heuristic 2:
#     Average Score: 304.20
#     Average Time: 1.3892 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=4) with Heuristic 1:
#     Average Score: 72.90
#     Average Time: 1.2043 seconds
#     Penetrance: 10.00%
#
#   Beam Search (w=4) with Heuristic 2:
#     Average Score: 304.20
#     Average Time: 1.8237 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 1:
#     Average Score: 68.30
#     Average Time: 0.0004 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 2:
#     Average Score: 270.90
#     Average Time: 0.0009 seconds
#     Penetrance: 0.00%
#
# ==================================================
# Results for m=75, n=43:
#   Hill Climbing with Heuristic 1:
#     Average Score: 74.30
#     Average Time: 0.0127 seconds
#     Penetrance: 50.00%
#
#   Hill Climbing with Heuristic 2:
#     Average Score: 354.70
#     Average Time: 0.0437 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=3) with Heuristic 1:
#     Average Score: 74.90
#     Average Time: 4.0078 seconds
#     Penetrance: 90.00%
#
#   Beam Search (w=3) with Heuristic 2:
#     Average Score: 356.40
#     Average Time: 6.1866 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=4) with Heuristic 1:
#     Average Score: 74.90
#     Average Time: 5.2396 seconds
#     Penetrance: 90.00%
#
#   Beam Search (w=4) with Heuristic 2:
#     Average Score: 356.70
#     Average Time: 8.0918 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 1:
#     Average Score: 65.80
#     Average Time: 0.0004 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 2:
#     Average Score: 267.70
#     Average Time: 0.0007 seconds
#     Penetrance: 0.00%
#
# ==================================================
# Results for m=75, n=78:
#   Hill Climbing with Heuristic 1:
#     Average Score: 74.80
#     Average Time: 0.0181 seconds
#     Penetrance: 80.00%
#
#   Hill Climbing with Heuristic 2:
#     Average Score: 387.60
#     Average Time: 0.1318 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=3) with Heuristic 1:
#     Average Score: 74.90
#     Average Time: 7.1208 seconds
#     Penetrance: 90.00%
#
#   Beam Search (w=3) with Heuristic 2:
#     Average Score: 388.60
#     Average Time: 10.9917 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=4) with Heuristic 1:
#     Average Score: 74.80
#     Average Time: 9.7844 seconds
#     Penetrance: 80.00%
#
#   Beam Search (w=4) with Heuristic 2:
#     Average Score: 389.50
#     Average Time: 14.6336 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 1:
#     Average Score: 66.20
#     Average Time: 0.0005 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 2:
#     Average Score: 265.90
#     Average Time: 0.0008 seconds
#     Penetrance: 0.00%
#
# ==================================================
# Results for m=150, n=10:
#   Hill Climbing with Heuristic 1:
#     Average Score: 140.80
#     Average Time: 0.0032 seconds
#     Penetrance: 0.00%
#
#   Hill Climbing with Heuristic 2:
#     Average Score: 565.20
#     Average Time: 0.0082 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=3) with Heuristic 1:
#     Average Score: 141.70
#     Average Time: 1.8303 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=3) with Heuristic 2:
#     Average Score: 566.00
#     Average Time: 2.9025 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=4) with Heuristic 1:
#     Average Score: 142.20
#     Average Time: 2.6021 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=4) with Heuristic 2:
#     Average Score: 566.00
#     Average Time: 3.6451 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 1:
#     Average Score: 135.30
#     Average Time: 0.0007 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 2:
#     Average Score: 528.80
#     Average Time: 0.0012 seconds
#     Penetrance: 0.00%
#
# ==================================================
# Results for m=150, n=43:
#   Hill Climbing with Heuristic 1:
#     Average Score: 146.90
#     Average Time: 0.0329 seconds
#     Penetrance: 0.00%
#
#   Hill Climbing with Heuristic 2:
#     Average Score: 662.40
#     Average Time: 0.1061 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=3) with Heuristic 1:
#     Average Score: 147.80
#     Average Time: 7.9467 seconds
#     Penetrance: 10.00%
#
#   Beam Search (w=3) with Heuristic 2:
#     Average Score: 663.10
#     Average Time: 12.0679 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=4) with Heuristic 1:
#     Average Score: 148.60
#     Average Time: 10.5972 seconds
#     Penetrance: 20.00%
#
#   Beam Search (w=4) with Heuristic 2:
#     Average Score: 663.10
#     Average Time: 16.1946 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 1:
#     Average Score: 135.50
#     Average Time: 0.0010 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 2:
#     Average Score: 531.50
#     Average Time: 0.0014 seconds
#     Penetrance: 0.00%
#
# ==================================================
# Results for m=150, n=78:
#   Hill Climbing with Heuristic 1:
#     Average Score: 148.70
#     Average Time: 0.0768 seconds
#     Penetrance: 30.00%
#
#   Hill Climbing with Heuristic 2:
#     Average Score: 710.00
#     Average Time: 0.3389 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=3) with Heuristic 1:
#     Average Score: 148.90
#     Average Time: 14.4991 seconds
#     Penetrance: 20.00%
#
#   Beam Search (w=3) with Heuristic 2:
#     Average Score: 711.50
#     Average Time: 21.9358 seconds
#     Penetrance: 0.00%
#
#   Beam Search (w=4) with Heuristic 1:
#     Average Score: 148.90
#     Average Time: 18.8845 seconds
#     Penetrance: 30.00%
#
#   Beam Search (w=4) with Heuristic 2:
#     Average Score: 712.50
#     Average Time: 29.1536 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 1:
#     Average Score: 132.00
#     Average Time: 0.0010 seconds
#     Penetrance: 0.00%
#
#   VND with Heuristic 2:
#     Average Score: 523.80
#     Average Time: 0.0022 seconds
#     Penetrance: 0.00%
#
# ==================================================
